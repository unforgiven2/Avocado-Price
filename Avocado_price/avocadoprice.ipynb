# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("avocado.csv")
df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df["Date"]=pd.to_datetime(df["Date"])
df
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df["AveragePrice"].mean()
# Out:
# 1.4059784097758825

# %%
list(set(df["region"].values.tolist()))
# Out:
# ['Northeast',
#  'Philadelphia',
#  'Plains',
#  'Boise',
#  'LasVegas',
#  'SouthCentral',
#  'Denver',
#  'BuffaloRochester',
#  'Boston',
#  'Portland',
#  'BaltimoreWashington',
#  'RaleighGreensboro',
#  'Houston',
#  'PhoenixTucson',
#  'Detroit',
#  'DallasFtWorth',
#  'GreatLakes',
#  'RichmondNorfolk',
#  'GrandRapids',
#  'Atlanta',
#  'Nashville',
#  'NewOrleansMobile',
#  'Columbus',
#  'Roanoke',
#  'Sacramento',
#  'Tampa',
#  'CincinnatiDayton',
#  'NewYork',
#  'NorthernNewEngland',
#  'Louisville',
#  'HartfordSpringfield',
#  'Midsouth',
#  'Albany',
#  'Orlando',
#  'Spokane',
#  'West',
#  'Jacksonville',
#  'WestTexNewMexico',
#  'SouthCarolina',
#  'TotalUS',
#  'Seattle',
#  'StLouis',
#  'SanDiego',
#  'LosAngeles',
#  'Pittsburgh',
#  'MiamiFtLauderdale',
#  'Syracuse',
#  'Southeast',
#  'SanFrancisco',
#  'Indianapolis',
#  'Chicago',
#  'California',
#  'Charlotte',
#  'HarrisburgScranton']

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
l=df.groupby("region")["AveragePrice"].mean() 
l
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Columbus               1.252781
# DallasFtWorth          1.085592
# Denver                 1.218580
# Detroit                1.276095
# GrandRapids            1.505000
# GreatLakes             1.338550
# HarrisburgScranton     1.513284
# HartfordSpringfield    1.818639
# Houston                1.047929
# Indianapolis           1.313994
# Jacksonville           1.510947
# LasVegas               1.380917
# LosAngeles             1.216006
# Louisville             1.286686
# MiamiFtLauderdale      1.428491
# Midsouth               1.404763
# Nashville              1.212101
# NewOrleansMobile       1.304793
# NewYork                1.727574
# ...

# %%
print("max price {} ".format(l.max()))
print("min price {}".format(l.min()))
print("avg price {}".format(l.mean()))
# Out:
# max price 1.818639053254438
# min price 1.0479289940828402
# avg price 1.4059546956211708

# %%
fig, ax =plt.subplots(figsize=(30,15))

ax.scatter( x=df["AveragePrice"], y=df["Date"])

# %%
c=df.groupby("type")["AveragePrice"].mean() 
c
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %%
print("Average avocado price per year {}".format(df.groupby("year")["AveragePrice"].mean()))
print(("Minimum avocado price per year {}".format(df.groupby("year")["AveragePrice"].min())))
print(("Maximum avocado price per year {}".format(df.groupby("year")["AveragePrice"].max())))
# Out:
# Average avocado price per year year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64
# Minimum avocado price per year year
# 2015    0.49
# 2016    0.51
# 2017    0.44
# 2018    0.56
# Name: AveragePrice, dtype: float64
# Maximum avocado price per year year
# 2015    2.79
# 2016    3.25
# 2017    3.17
# 2018    2.30
# Name: AveragePrice, dtype: float64

# %%
mask = df['type']=='conventional'
g = sns.factorplot('AveragePrice','region',data=df[mask],
                   hue='year',
                   size=8,
                   aspect=0.6,
                   join=False,
              )
# Out:
# C:\Users\cenkg\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\cenkg\anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\cenkg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby("region")["Total Volume"].mean()
# Out:
# region
# Albany                 4.753787e+04
# Atlanta                2.621453e+05
# BaltimoreWashington    3.985619e+05
# Boise                  4.264257e+04
# Boston                 2.877929e+05
# BuffaloRochester       6.793630e+04
# California             3.044324e+06
# Charlotte              1.051939e+05
# Chicago                3.955690e+05
# CincinnatiDayton       1.317219e+05
# Columbus               8.873776e+04
# DallasFtWorth          6.166251e+05
# Denver                 4.109542e+05
# Detroit                1.876403e+05
# GrandRapids            8.938383e+04
# GreatLakes             1.744505e+06
# HarrisburgScranton     1.236948e+05
# HartfordSpringfield    1.499128e+05
# Houston                6.010884e+05
# Indianapolis           8.953666e+04
# Jacksonville           8.517753e+04
# LasVegas               1.608784e+05
# LosAngeles             1.502653e+06
# Louisville             4.762427e+04
# MiamiFtLauderdale      2.889740e+05
# Midsouth               1.503992e+06
# ...
